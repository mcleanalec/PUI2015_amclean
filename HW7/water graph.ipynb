# %%
import pandas as pd
import pylab as pl
pl.style.use('fivethirtyeight')

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
water = pd.read_csv('water.csv')

# %%
water
# Out:
#     Year  NYC Consumption(Million gallons per day)  \
# 0   1979                                    1512.4
# 1   1980                                    1505.9
# 2   1981                                    1309.3
# 3   1982                                    1382.4
# 4   1983                                    1423.8
# 5   1984                                    1465.0
# 6   1985                                    1325.8
# 7   1986                                    1350.7
# 8   1987                                    1446.5
# 9   1988                                    1483.9
# 10  1989                                    1401.7
# 11  1990                                    1423.8
# 12  1991                                    1496.3
# 13  1992                                    1368.6
# 14  1993                                    1368.5
# 15  1994                                    1357.7
# 16  1995                                    1325.7
# ...

# %%
#creating a date range
time = pd.date_range('1/1/1979', periods=31, freq='A')

# %%
#using appropriate colors
kelly_colors_hex = [
    '#FFB300', # Vivid Yellow
    '#803E75', # Strong Purple
    '#FF6800', # Vivid Orange
    '#A6BDD7', # Very Light Blue
    '#C10020', # Vivid Red
    '#CEA262', # Grayish Yellow
    '#817066', # Medium Gray
    '#007D34', # Vivid Green
    '#F6768E', # Strong Purplish Pink
    '#00538A', # Strong Blue
    '#FF7A5C', # Strong Yellowish Pink
    '#53377A', # Strong Violet
    '#FF8E00', # Vivid Orange Yellow
    '#B32851', # Strong Purplish Red
    '#F4C800', # Vivid Greenish Yellow
    '#7F180D', # Strong Reddish Brown
    '#93AA00', # Vivid Yellowish Green
    '#593315', # Deep Yellowish Brown
    '#F13A13', # Vivid Reddish Orange
    '#232C16', # Dark Olive Green
    ]

# %%
figure, ax = subplots(figsize=(12,10))
ax.plot(time, water['NYC Consumption(Million gallons per day)'], c='#00538A')
ax.set_title('Consumption of water in NYC', fontsize=22)
ax.set_ylabel('Millions of gallons per day', fontsize=16)
ax.grid(False)
pl.figtext(.06, .06, "Source: NYC Open Data--Water Consumption in NYC")
ax.patch.set_facecolor('#817066')
